# %% [markdown]
# # define

# %%
# %matplotlib inline
from __future__ import print_function
# import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def print_list_prec(x , prec):
    print ("printing by num:")
    i = 0
    print("\n*********************************************************************************\n")  
    global for_flag
    for_flag = 0
    for i in range(0, 20, +1):
        for j in range(0, 10, +1):
            if((i*10+j)>=len(x)):
                for_flag=1
                break
            print ((round(x[i*10+j], prec)), end='\t')
        print('')    
        if(for_flag==1):
            break
    print("\n*********************************************************************************\n")

# %%
def change_to_normal(target_list,item,value):
    for i in range(0, (len(target_list)), +1):
        if(target_list[i]==item):
            target_list[i]=value

# %%
# write_f = open("test.hooklog","r+")
# write_f.write("test1\n")
# write_f.write("test2\n")
# write_f.write("test3\n")
# write_f.close()

# %% [markdown]
# # start

# %%
f = open('test.hooklog', 'r')
# print (f.read())
b = []
a = f.readlines() 
for i in range(0, (len(a)), +1):
    if((a[i][0])=='#'):
        b.append(a[i+1][0])

# %%
print (len(a))
print (a[i])
print (a[i][0])
print ((len(b)))
# Out:
# 463
# Return=a4
# R
# 109

# %%
print (b)
# Out:
# ['L', 'L', 'L', 'L', 'L', 'L', 'L', 'R', 'R', 'L', 'R', 'C', 'R', 'R', 'R', 'L', 'R', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'C', 'C', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'C', 'C', 'C', 'C', 'C', 'R', 'R', 'R', 'R', 'R', 'C', 'C', 'C', 'C', 'C', 'C', 'C']

# %%
global for_flag
for_flag = 0
for i in range(0, 28, +1):
    for j in range(0, 28, +1):
        if((i*28+j)>=len(b)):
            for_flag=1
            break
        print (b[i*28+j], end='')
    print('')    
    if(for_flag==1):
        break
# Out:
# LLLLLLLRRLRCRRRLRLLLLLLLCCRR
# RRRRRRRRRRRRRRRRRRRRRRRRRRRR
# RRRRRRRRRRRRRRRRRRRRRRRRRRRR
# RRRRRRRRCCCCCRRRRRCCCCCCC

# %%
global for_flag
for_flag = 0
for i in range(0, 20, +1):
    for j in range(0, 10, +1):
        if((i*10+j)>=len(b)):
            for_flag=1
            break
        print (b[i*10+j], end='')
#         print (i*10+j, end=' ')
    print('')    
    if(for_flag==1):
        break
 
myset = set(b)
for item in myset:
  print("the %s has found %d" %(item,b.count(item)))
# Out:
# LLLLLLLRRL
# RCRRRLRLLL
# LLLLCCRRRR
# RRRRRRRRRR
# RRRRRRRRRR
# RRRRRRRRRR
# RRRRRRRRRR
# RRRRRRRRRR
# RRRRRRRRRR
# RRCCCCCRRR
# RRCCCCCCC
# the L has found 16
# the R has found 78
# the C has found 15

# %%
# import numpy as np
# out = np.array(shape=(500,2), dtype=dt)
list_test = [[None] * 2 for i in range(1000)]

# print (len(list_test),len(list_test[0]))

list_counter = 0
for i in range(0, (len(a)), +1):
    if((a[i][0])=='#'):
        list_test[list_counter][0] = a[i].replace("#", "").replace("\n", "")
        list_test[list_counter][1] = a[i+1]
        list_counter += 1
        
# print (list_counter)     
# print (list_test)

list_test2 = [[] * 0 for i in range(2)]
# print (len(list_test2),len(list_test2[0]))
list_counter = 0
for i in range(0, (len(a)), +1):
    if((a[i][0])=='#'):
        list_test2[0].append(int(a[i].replace("#", "").replace("\n", "")))
        list_test2[1].append(a[i+1])
        list_counter += 1

# print (list_test2[0][0])     
# print (len(list_test2),len(list_test2[0]))
for i in range(0, (len(list_test2[0])), +1):
    print(list_test2[0][i],"\t",list_test2[1][i],end="")

    
# print(list_test2)
# list_test2[0].sort()
print (type(list_test2[0]))
# from operator import itemgetter, attrgetter
# sorted(list_test2, key=itemgetter(0))
s = sorted(list_test2, key = lambda x:x[0])
print("**********************************************************")
print (s)
for i in range(0, (len(list_test2[0])), +1):
    print(list_test2[0][i],"\t",list_test2[1][i],end="")
# Out:
# 226190000 	 LoadLibrary
# 227020000 	 LoadLibrary
# 226740000 	 LoadLibrary
# 225940000 	 LoadLibrary
# 227160000 	 LoadLibrary
# 227320000 	 LoadLibrary
# 227630000 	 LoadLibrary
# 228070000 	 RegQueryValue
# 228080000 	 RegQueryValue
# 227770000 	 LoadLibrary
# 228580000 	 RegQueryValue
# 229630000 	 CreateFile
# 229870000 	 RegQueryValue
# 229880000 	 RegQueryValue
# 229890000 	 RegEnumValue
# 228870000 	 LoadLibrary
# 230640000 	 RegQueryValue
# 230640000 	 LoadLibrary
# 230090000 	 LoadLibrary
# 228120000 	 LoadLibrary
# 231030000 	 LoadLibrary
# 231130000 	 LoadLibrary
# 231440000 	 LoadLibrary
# 231620000 	 LoadLibrary
# 232010000 	 CreateFile
# 232010000 	 CreateFile
# 232990000 	 RegCreateKey
# 233080000 	 RegSetValue
# 233130000 	 RegCreateKey
# 233160000 	 RegSetValue
# 233450000 	 RegQueryValue
# 233460000 	 RegQueryValue
# 233460000 	 RegQueryValue
# 233470000 	 RegQueryValue
# 233470000 	 RegQueryValue
# 233480000 	 RegQueryValue
# 233480000 	 RegQueryValue
# ...

# %%
print(out[0][0])
print(out[0][1])
print(out[1][0])
print(out[1][1])
print(out[0][0])

# %%
change_normal = ourstr
myset = set(ourstr)
print("%d items found\n" %(len(ourstr)))
for item in myset:
    print("%s%d" %(item,ourstr.count(item)))
    change_to_normal(change_normal,item,(ourstr.count(item)/(len(ourstr))))

# %%
pic_num = math.ceil(len(change_normal)/10)*10

while(len(change_normal)<= pic_num - 1):
    change_normal.append(0)

# %%
global for_flag
for_flag = 0
for i in range(0, 20, +1):
    for j in range(0, 10, +1):
        if((i*10+j)>=len(b)):
            for_flag=1
            break
        print (b[i*10+j], end='')
#         print (i*10+j, end=' ')
    print('')    
    if(for_flag==1):
        break
 
myset = set(b)
for item in myset:
  print("the %s has found %d" %(item,b.count(item)))

print (print_list_prec(change_normal,4))
np_pic = np.asarray(change_normal)


plt.imshow(np_pic.reshape([int(len(change_normal)/10),10]), cmap='Greys')  
plt.show()

# %%
f.close()

# %%
student_objects = [
        Student('john', 'A', 15),
        Student('jane', 'B', 12),
        Student('dave', 'B', 10),
]

# %%
list_test = []

list_counter = 0
for i in range(0, (len(a)), +1):
    if((a[i][0])=='#'):
        list_test.append([(int(a[i].replace("#", "").replace("\n", ""))),a[i+1]])
        list_counter += 1


print ("list shape:",len(list_test),len(list_test[0]))        
print ("list_counter:",list_counter)     
for aaa in list_test:
    print (aaa[0],aaa[1],end="")
print ("*****************************************")
s = sorted(list_test, key = lambda x : x[0])
for aaa in s:
    print (aaa[0],aaa[1],end="")
    
    
for aaa in s:
    print (aaa[0])
# Out:
# list shape: 109 2
# list_counter: 109
# 226190000 LoadLibrary
# 227020000 LoadLibrary
# 226740000 LoadLibrary
# 225940000 LoadLibrary
# 227160000 LoadLibrary
# 227320000 LoadLibrary
# 227630000 LoadLibrary
# 228070000 RegQueryValue
# 228080000 RegQueryValue
# 227770000 LoadLibrary
# 228580000 RegQueryValue
# 229630000 CreateFile
# 229870000 RegQueryValue
# 229880000 RegQueryValue
# 229890000 RegEnumValue
# 228870000 LoadLibrary
# 230640000 RegQueryValue
# 230640000 LoadLibrary
# 230090000 LoadLibrary
# 228120000 LoadLibrary
# 231030000 LoadLibrary
# 231130000 LoadLibrary
# 231440000 LoadLibrary
# 231620000 LoadLibrary
# 232010000 CreateFile
# 232010000 CreateFile
# 232990000 RegCreateKey
# 233080000 RegSetValue
# 233130000 RegCreateKey
# 233160000 RegSetValue
# 233450000 RegQueryValue
# 233460000 RegQueryValue
# 233460000 RegQueryValue
# 233470000 RegQueryValue
# 233470000 RegQueryValue
# 233480000 RegQueryValue
# 233480000 RegQueryValue
# 233490000 RegQueryValue
# ...
